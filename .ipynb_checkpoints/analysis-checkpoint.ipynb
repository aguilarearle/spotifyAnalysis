# %% [markdown]
# I am using the Spotify API performn some exploratory data analysis.

# %%
TOKEN = 'BQAyMd3uh79mIlS4OsBImRzWzF6ixa6wcBwnfZljMboF51U9rGwlmcs3rnwxussGlM98n7HIwwSv9PLQwVt6mrKscQMfEaFdmMsLtbyb1XbjZ7fozw-gj78R9oRmhZlCrc-UsUvJ75yX5UPJupNOQ9zVsWk62Gj4JkS8QznSQisIgvEv'

# %%
import json
import requests
import urllib

from furl import furl
from math import ceil

import matplotlib

import urllib.request
import scipy.io.wavfile
import pydub
from random import shuffle

import numpy as np
from numpy import array

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns


import librosa 
import librosa.display

# %matplotlib inline

# %%
SONG_FOLDER = '/home/lildreamz/Programming/jupyter_notebooks/spotifyAnalysis/songs/'


url = "https://api.spotify.com/v1/me/tracks"
headers = {'Authorization': "Bearer {}".format(TOKEN)}
r = requests.get(url, headers=headers)
parsed = json.loads(r.text)
count_songs = parsed["total"]
print("Total number of songs: {}".format(count_songs))
# Out:
# Total number of songs: 830

# %%
all_songs = []

for i in range(int(ceil(count_songs/50.0))):
    offset = 50*i
    url = "https://api.spotify.com/v1/me/tracks?limit=50&offset={}".format(offset)
    headers = {'Authorization': "Bearer {}".format(TOKEN)}
    r = requests.get(url, headers=headers)
    parsed = json.loads(r.text)
    
    all_songs.extend(parsed["items"])
    
print("Number of gathered songs: {}".format(len(all_songs)))
# Out:
# Number of gathered songs: 830

# %%
print(all_songs[0]['track'].keys())
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
web_file="http://p.scdn.co/mp3-preview/35b4ce45af06203992a86fa729d17b1c1f93cac5"
# Download file
data = urllib.request.urlretrieve(web_file,SONG_FOLDER+"testFile.mp3")
mp3 = pydub.AudioSegment.from_mp3(SONG_FOLDER + "testFile.mp3")
mp3.export(SONG_FOLDER+"testFile.wav", format="wav")

rate, audData  = scipy.io.wavfile.read(SONG_FOLDER+"testFile.wav")

# %% [markdown]
# # Mel Spectogram

# %%
audio_path = SONG_FOLDER + 'testFile.wav'
y, sr = librosa.load(audio_path)
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128) 
log_S = librosa.power_to_db(S, ref=np.max)
plt.figure(figsize=(12, 4))

librosa.display.specshow(log_S, sr=sr, x_axis = 'time', y_axis='mel')
 
plt.title('mel power spectrogram')

# draw a color bar
plt.colorbar(format='%+02.0f dB')

# Make the figure layout compact
plt.tight_layout()

# %% [markdown]
# # Harmonic-percussive source separation
#
# The aim of the Harmonic/Percussive separation is to decompose the original music signal to the harmonic (i.e. pitched instruments) and the percussive (non pitched instruments, percussion) parts of the signal. Such methods can be applied to audio mixing software, or can be adopted as preprocessing on other Music Information Retrieval Methods such as rhythm analysis or chord/tonality recognition.

# %%
y_harmonic, y_percussive = librosa.effects.hpss(y)

# %%
# Ddisplay a mel-scaled power (energy-squared) spectrogram
S_harmonic   = librosa.feature.melspectrogram(y_harmonic, sr=sr)
S_percussive = librosa.feature.melspectrogram(y_percussive, sr=sr)

# Convert to log scale (dB). Use the peak power as reference.
log_Sh = librosa.power_to_db(S_harmonic, ref=np.max)
log_Sp = librosa.power_to_db(S_percussive, ref=np.max)

plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
librosa.display.specshow(log_Sh, sr=sr, y_axis='mel')
plt.title('mel power spectrogram (Harmonic)')
plt.colorbar(format='%+02.0f dB')

plt.subplot(2,1,2)
librosa.display.specshow(log_Sp, sr=sr, x_axis='time', y_axis='mel')
plt.title('mel power spectrogram (Percussive)')
plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %% [markdown]
# # Chromagram
#
# Pitch class (or chroma) representations
# are often used to encode harmony while suppressing variations
# in octave height, loudness, or timbre.

# %%
from palettable.cartocolors.sequential import Sunset_7_r

# Using a CQT-based chromagram here.  
# Use the harmonic component to avoid pollution from transients
D = librosa.feature.chroma_cqt(y=y_harmonic, sr=sr)

plt.figure(figsize=(12,4))

librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1,  cmap = Sunset_7_r.mpl_colormap)
plt.title('Chromagram')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# # MFCC
# Mel-frequency cepstral coefficients are commonly used to represent **texture** or **timbre** of sound.
#
# In music, **texture** is how the melodic, rhythmic, and harmonic materials are combined in a composition, thus determining the overall quality of the sound in a piece. Texture is often described in regard to the density, or thickness, and range, or width, between lowest and highest pitches, in relative terms as well as more specifically distinguished according to the number of voices, or parts, and the relationship between these voices. For example, a thick texture contains many “layers” of instruments.
#
#
# **Timbre** is the perceived sound quality of a musical note, sound or tone.
#
#
# #### Mel-Frequency cepstrum
#
# In sound processing, the **mel-frequency cepstrum (MFC)** is a representation of the short-term power spectrum of a sound, based on a linear cosine transform of a log power spectrum on a nonlinear mel scale of frequency.
#
# **power spectrum:**
#
# For a given signal, the power spectrum gives a plot of the portion of a signal's power (energy per unit time) falling within given frequency bins

# %%
# Next, we'll extract the top 13 Mel-frequency cepstral coefficients (MFCCs)
mfcc        = librosa.feature.mfcc(S=log_S, n_mfcc=13)

# Let's pad on the first and second deltas while we're at it
delta_mfcc  = librosa.feature.delta(mfcc)
delta2_mfcc = librosa.feature.delta(mfcc, order=2)

# How do they look?  We'll show each in its own subplot
plt.figure(figsize=(12, 6))

plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

plt.subplot(3,1,2)
librosa.display.specshow(delta_mfcc)
plt.ylabel('MFCC-$\Delta$')
plt.colorbar()

plt.subplot(3,1,3)
librosa.display.specshow(delta2_mfcc, sr=sr, x_axis='time')
plt.ylabel('MFCC-$\Delta^2$')
plt.colorbar()

plt.tight_layout()

# For future use, we'll stack these together into one matrix
M = np.vstack([mfcc, delta_mfcc, delta2_mfcc])
# Out:
# /home/lildreamz/anaconda3/lib/python3.7/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %% [markdown]
# # Beat tracking
#
# Beat tracker returns an estimate of the tempo (beats/min) and frame indices of beat events.

# %%
# Now, let's run the beat tracker.
# We'll use the percussive component for this part
plt.figure(figsize=(12, 6))
tempo, beats = librosa.beat.beat_track(y=y_percussive, sr=sr)
# Let's re-draw the spectrogram, but this time, overlay the detected beats
plt.figure(figsize=(12,4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

# Let's draw transparent lines over the beat frames
plt.vlines(librosa.frames_to_time(beats),
           1, 0.5 * sr,
           colors='w', linestyles='-', linewidth=2, alpha=0.5)

plt.axis('tight')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()
# Out:
# /home/lildreamz/anaconda3/lib/python3.7/site-packages/scipy/fftpack/basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x

# %%
url = "https://api.spotify.com/v1/me/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN)}
r = requests.get(url, headers=headers)
parsed = json.loads(r.text)

# %%
playlists = parsed['items']
for playlist in playlists:
    if playlist['collaborative'] == True:
        print(playlist)
# Out:
# {'collaborative': True, 'external_urls': {'spotify': 'https://open.spotify.com/playlist/4zPScbIBFDKIKtCM3PvuJV'}, 'href': 'https://api.spotify.com/v1/playlists/4zPScbIBFDKIKtCM3PvuJV', 'id': '4zPScbIBFDKIKtCM3PvuJV', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/797e59fba47111923b437733b8bd0ceb03b795758b8c2d541300c4d13eb1cb5be80c26c1a94956fc92501ad97eba0f22b05aca03d90937dc4af2735ba0ce5df98bce411863c24fa4904523bc5030affe', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/797e59fba47111923b437733b8bd0ceb03b795758b8c2d541300c4d13eb1cb5be80c26c1a94956fc92501ad97eba0f22b05aca03d90937dc4af2735ba0ce5df98bce411863c24fa4904523bc5030affe', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/797e59fba47111923b437733b8bd0ceb03b795758b8c2d541300c4d13eb1cb5be80c26c1a94956fc92501ad97eba0f22b05aca03d90937dc4af2735ba0ce5df98bce411863c24fa4904523bc5030affe', 'width': 60}], 'name': 'earle and tiff ', 'owner': {'display_name': 'Tiffany Koval', 'external_urls': {'spotify': 'https://open.spotify.com/user/tknoodle1'}, 'href': 'https://api.spotify.com/v1/users/tknoodle1', 'id': 'tknoodle1', 'type': 'user', 'uri': 'spotify:user:tknoodle1'}, 'primary_color': None, 'public': False, 'snapshot_id': 'NDcsMGFiNGY5YWU0ODU2MmNhY2E0ZjEyNTczZjhlZjRjYzc1ODY5MzY5YQ==', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/4zPScbIBFDKIKtCM3PvuJV/tracks', 'total': 45}, 'type': 'playlist', 'uri': 'spotify:user:tknoodle1:playlist:4zPScbIBFDKIKtCM3PvuJV'}

# %%
playlist_Id = '4zPScbIBFDKIKtCM3PvuJV'

# %%
url = "https://api.spotify.com/v1/playlists/4zPScbIBFDKIKtCM3PvuJV"
headers = {'Authorization': "Bearer {}".format(TOKEN)}
r = requests.get(url, headers=headers)
parsed = json.loads(r.text)

# %%
total_songs = parsed['tracks']['total']

# %%
parsed['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
parsed['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
parsed['tracks']['items'][0]['added_by']['id']
# Out:
# 'tknoodle1'

# %%
parsed['tracks']['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
parsed['tracks']['items'][0]['track']['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/9a55649cd7f1c63798f184c2f4ea6aba34daf4b9?cid=08c15eb1ecef4a339c36fea26459ea5d'

# %%
parsed['tracks']['items'][0]['track']['name']
# Out:
# 'BULLETS'

# %%
songs = parsed['tracks']['items']
meta_data = []


for song in songs:
    added_by = song['added_by']['id']
    name = song['track']['name']
    name = name.replace(" ", "")
    web_file = song['track']['preview_url']
    if web_file == None:
        meta_data.append({"add_by": added_by, "name": name, "filename": "NoFile"})
        continue
    filename = added_by + "_" + name 
    meta_data.append({"add_by": added_by, "name": name, "filename": filename})
    print("Song name: %s. Was added by: %s.\nFILENAME: %s. link=%s\n"%(name, added_by, filename, web_file))
    # Download file
    data = urllib.request.urlretrieve(web_file,SONG_FOLDER + filename + ".mp3")
    mp3 = pydub.AudioSegment.from_mp3(SONG_FOLDER + filename + ".mp3")
    mp3.export(SONG_FOLDER + filename +".wav", format="wav")
    rate, audData  = scipy.io.wavfile.read(SONG_FOLDER+"file.wav")
    print("rate: %r\n"%(rate))
# Out:
# Song name: BULLETS. Was added by: tknoodle1.
# FILENAME: tknoodle1_BULLETS. link=https://p.scdn.co/mp3-preview/9a55649cd7f1c63798f184c2f4ea6aba34daf4b9?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: HidingInTheMelody. Was added by: tknoodle1.
# FILENAME: tknoodle1_HidingInTheMelody. link=https://p.scdn.co/mp3-preview/cd1282e43fb5a938ccd6e5599b6d57a714ebff79?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: InChains. Was added by: earleag.
# FILENAME: earleag_InChains. link=https://p.scdn.co/mp3-preview/29bdfb733818801d2ce78b2a71fc0ef5f2de7139?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Unspoken. Was added by: tknoodle1.
# FILENAME: tknoodle1_Unspoken. link=https://p.scdn.co/mp3-preview/270965080f6908ea293716e0c153f12f561f7b03?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: FakeID. Was added by: tknoodle1.
# FILENAME: tknoodle1_FakeID. link=https://p.scdn.co/mp3-preview/be77778e775ab289c54db9aad6015aa88577dec7?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Elastic. Was added by: tknoodle1.
# FILENAME: tknoodle1_Elastic. link=https://p.scdn.co/mp3-preview/8bedd3c7759306f335b03b0f806330c1f7f7b171?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Love&Pain(KaytranadaRemix). Was added by: tknoodle1.
# FILENAME: tknoodle1_Love&Pain(KaytranadaRemix). link=https://p.scdn.co/mp3-preview/52d5bd6832249d7d0db1948506c4c673fb5422e3?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: IEnter-OriginalMix. Was added by: tknoodle1.
# FILENAME: tknoodle1_IEnter-OriginalMix. link=https://p.scdn.co/mp3-preview/2a993352491b28147ed64d938f9eef277d2e9467?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: PS. Was added by: tknoodle1.
# FILENAME: tknoodle1_PS. link=https://p.scdn.co/mp3-preview/86b03cb272033bd651b179ba5b1014107b0bee3b?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Baby. Was added by: earleag.
# FILENAME: earleag_Baby. link=https://p.scdn.co/mp3-preview/cad8d4fbf9df1ff911e5c97be3001fe51b88eb60?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Aurra. Was added by: tknoodle1.
# FILENAME: tknoodle1_Aurra. link=https://p.scdn.co/mp3-preview/a6c8a174e33ab8eb89f1fe791478de8934bdce17?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Lying&Loving(feat.Mothica). Was added by: earleag.
# FILENAME: earleag_Lying&Loving(feat.Mothica). link=https://p.scdn.co/mp3-preview/5af47f0bec56e7e792db857a9c07aa9dc632042e?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Daybreak. Was added by: earleag.
# FILENAME: earleag_Daybreak. link=https://p.scdn.co/mp3-preview/ab237a598e3c1dd412123d9e9f9cbe224928e1f3?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: StopIt. Was added by: tknoodle1.
# FILENAME: tknoodle1_StopIt. link=https://p.scdn.co/mp3-preview/13b2ef61497e4f338a9d2928b1f3136a3606bca6?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: AllFortheGram(feat.Sophiegrophy). Was added by: tknoodle1.
# FILENAME: tknoodle1_AllFortheGram(feat.Sophiegrophy). link=https://p.scdn.co/mp3-preview/6ef653b0a628a6578ad25428659f96ebb4ad9e21?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: FUN!. Was added by: tknoodle1.
# FILENAME: tknoodle1_FUN!. link=https://p.scdn.co/mp3-preview/05a45ab77b8f30f0068c8522e56e71eadf6d55e4?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Dreganomics. Was added by: tknoodle1.
# FILENAME: tknoodle1_Dreganomics. link=https://p.scdn.co/mp3-preview/be93d08e33abc61e0eb7cfa062662375c3d193b3?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: NedFlanders(feat.A$APFerg). Was added by: tknoodle1.
# FILENAME: tknoodle1_NedFlanders(feat.A$APFerg). link=https://p.scdn.co/mp3-preview/a2d3fb76b958249755e7099e2e73a87666f2f627?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: 10FreakyGirls(with21Savage). Was added by: tknoodle1.
# FILENAME: tknoodle1_10FreakyGirls(with21Savage). link=https://p.scdn.co/mp3-preview/053449b50d89d92d5bfaa95ef721694bdea89901?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: SpaceCadet(feat.Gunna). Was added by: tknoodle1.
# FILENAME: tknoodle1_SpaceCadet(feat.Gunna). link=https://p.scdn.co/mp3-preview/13dd3df282a9f602c0445bec1a3a946caa4a00d4?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Bounce. Was added by: earleag.
# FILENAME: earleag_Bounce. link=https://p.scdn.co/mp3-preview/fd6b2f9c4d6f4b053884f72b61bc24a3a98f4dda?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: BadBadNews. Was added by: earleag.
# FILENAME: earleag_BadBadNews. link=https://p.scdn.co/mp3-preview/82b8702aa0cd4995ecd7ff37ead0fc9406e24033?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Look@Ugo. Was added by: earleag.
# FILENAME: earleag_Look@Ugo. link=https://p.scdn.co/mp3-preview/a8a8bf7d36cb9144881090e1e151b897095bbaae?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Rockets(feat.MoeMoks). Was added by: tknoodle1.
# FILENAME: tknoodle1_Rockets(feat.MoeMoks). link=https://p.scdn.co/mp3-preview/455ab300ceae179f0147bb1c86ee482f4b859b91?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: 86(feat.CubanDoll&ALLBLACK). Was added by: tknoodle1.
# FILENAME: tknoodle1_86(feat.CubanDoll&ALLBLACK). link=https://p.scdn.co/mp3-preview/34359358084ec476fa09c7b6d553b88537d3bfe0?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Caroline. Was added by: tknoodle1.
# FILENAME: tknoodle1_Caroline. link=https://p.scdn.co/mp3-preview/42bc90cc118abbfab92733c516d73f5ca130955e?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: FortheLoveofYou,Pts.1&2. Was added by: tknoodle1.
# FILENAME: tknoodle1_FortheLoveofYou,Pts.1&2. link=https://p.scdn.co/mp3-preview/dc7643ef236a1e6770475d70c71b5d7dcbb3ebe5?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Shine. Was added by: tknoodle1.
# FILENAME: tknoodle1_Shine. link=https://p.scdn.co/mp3-preview/64b14e912279f6a09eaa97b0aefcbd48ec452d85?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: NightJob. Was added by: earleag.
# FILENAME: earleag_NightJob. link=https://p.scdn.co/mp3-preview/e081e61d574bb640d460479200fc2a914056a8bb?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: 666(feat.YoungBoyNeverBrokeAgain). Was added by: tknoodle1.
# FILENAME: tknoodle1_666(feat.YoungBoyNeverBrokeAgain). link=https://p.scdn.co/mp3-preview/672cab6f45285169466a9451d236886152a655bd?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: LookWhatUStarted. Was added by: tknoodle1.
# FILENAME: tknoodle1_LookWhatUStarted. link=https://p.scdn.co/mp3-preview/8101cb0c362585c3274396968b0128a5fc6dcb6b?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: InMyCar. Was added by: tknoodle1.
# FILENAME: tknoodle1_InMyCar. link=https://p.scdn.co/mp3-preview/59337684fa87dcd1e86708e802c871a2245bfc1d?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: SaveAllThatLove(feat.Mozzy,MistahF.A.B.&NefThePharaoh). Was added by: tknoodle1.
# FILENAME: tknoodle1_SaveAllThatLove(feat.Mozzy,MistahF.A.B.&NefThePharaoh). link=https://p.scdn.co/mp3-preview/fe128da105ca48dce43ffdb5a3779eda995e5568?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: SideB[DopeSong]. Was added by: earleag.
# FILENAME: earleag_SideB[DopeSong]. link=https://p.scdn.co/mp3-preview/076012c10c57f4f8ef07faa275b815643fab96ad?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Dubstep(feat.Scrufizzer). Was added by: earleag.
# FILENAME: earleag_Dubstep(feat.Scrufizzer). link=https://p.scdn.co/mp3-preview/1c82fb357f11ba9348847901070fd31d3fdee016?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Lie4. Was added by: earleag.
# FILENAME: earleag_Lie4. link=https://p.scdn.co/mp3-preview/8b7407df64bc18d29118d962bf8fd8f56bf7c0e1?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: IWill. Was added by: earleag.
# FILENAME: earleag_IWill. link=https://p.scdn.co/mp3-preview/b7d3488ae51bd7eeb8bdb18caec6d64080c868f7?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Casio. Was added by: tknoodle1.
# FILENAME: tknoodle1_Casio. link=https://p.scdn.co/mp3-preview/16ac37daf91134e164861b6a1606c67fd8a1a9f5?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: Fades. Was added by: earleag.
# FILENAME: earleag_Fades. link=https://p.scdn.co/mp3-preview/afffdda487955e7179b039bac0702822554c156d?cid=08c15eb1ecef4a339c36fea26459ea5d
# rate: 44100
#
# Song name: HearFromYou. Was added by: earleag.
# FILENAME: earleag_HearFromYou. link=https://p.scdn.co/mp3-preview/3e402f5670c6402d6dcd2b9e5e460f0f854440fa?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: WarmAnimal. Was added by: earleag.
# FILENAME: earleag_WarmAnimal. link=https://p.scdn.co/mp3-preview/7b8bc9b60ca2029561936eb4e9e1ef51590d36aa?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100
#
# Song name: TheTipOut. Was added by: tknoodle1.
# FILENAME: tknoodle1_TheTipOut. link=https://p.scdn.co/mp3-preview/cbb0d4c1e7d3c8152dbfd21219c7472a648e3e64?cid=08c15eb1ecef4a339c36fea26459ea5d
#
# rate: 44100

# %%
from palettable.colorbrewer.sequential import GnBu_9_r
from palettable.cartocolors.sequential import Sunset_7_r
DATA_FOLDER = '/home/lildreamz/Programming/jupyter_notebooks/spotifyAnalysis/'
chromas = []
e_chromas = []
t_chromas = []
meta_data = np.load(DATA_FOLDER+"playlist_meta_data.npy")
#plt.figure(figsize=(12,4))
#gs1 = gridspec.GridSpec(6, 7)
#gs1.update(wspace=0.0, hspace=0.0)
gs_ix = 0

for file in meta_data:    
    if file['filename'] == "NoFile":
        continue
    add_by = file['add_by']    
    filename = file['filename']+".wav"
    song_name = file['name']
    audio_path = SONG_FOLDER + filename
    y, sr = librosa.load(audio_path)
    y_harmonic, y_percussive = librosa.effects.hpss(y)
    C = librosa.feature.chroma_cqt(y=y_harmonic, sr=sr)
    if add_by == 'tknoodle1':
        t_chromas.append({"chroma": C, "sr": sr })
    elif add_by == 'earleag':
        e_chromas.append({"chroma": C, "sr": sr})
    chromas.append({"add_by": add_by, "chroma": C, "sr": sr, "name": song_name})
    gs_ix = gs_ix + 1

# %%
from palettable.colorbrewer.sequential import GnBu_9_r
from palettable.matplotlib import Viridis_3
from palettable.cartocolors.sequential import Sunset_7_r



plt.figure(figsize=(14,12))
gs1 = gridspec.GridSpec(6, 7)
gs1.update(wspace=0.0, hspace=0.0)
gs_ix = 0

all_indices = set(list(range(0,42)))
e_indices = set([0,1,5,7,8,10,12,13,15,17,18,23,24,30,37])
t_indices = all_indices - e_indices

_e_chroma = e_chromas.copy()
_t_chroma = t_chromas.copy()


shuffle(_e_chroma)
shuffle(_t_chroma)
for e in e_indices:
    plt.subplot(gs1[e])
    c = _e_chroma.pop()
    librosa.display.specshow(c['chroma'], sr=c['chroma'], 
                         vmin=0, vmax=1,  cmap =  plt.get_cmap('Purples_r'))
    
for t in t_indices:
    plt.subplot(gs1[t])
    c = _t_chroma.pop()
    librosa.display.specshow(c['chroma'], sr=c['sr'], 
                         vmin=0, vmax=1,  
                             cmap =plt.get_cmap('RdPu_r'))
    
plt.savefig("BuPu_tree.png")

# %%
plt.figure(figsize=(12,6))
gs1 = gridspec.GridSpec(6, 7)
gs1.update(wspace=0.0, hspace=0.0)
gs_ix = 0

for chroma in chromas:
    plt.subplot(gs1[gs_ix])
    
    gs_ix = gs_ix + 1    
    if chroma['name'] == 'Dreganomics' or chroma['name'] == 'Casio' or chroma['name'] == 'Fades' or chroma['name'] == 'Look@Ugo':
        librosa.display.specshow(chroma['chroma'], sr=chroma['sr'], 
                                 vmin=0, vmax=1,  
                                 cmap = plt.get_cmap('YlGnBu_r'))
    elif chroma['add_by'] == 'tknoodle1':
        librosa.display.specshow(chroma['chroma'], 
                                sr=chroma['sr'], 
                               vmin=0, vmax=1,  
                              cmap = plt.get_cmap('RdPu_r'))
    elif chroma['add_by'] == 'earleag':        
        librosa.display.specshow(chroma['chroma'], 
                                 sr=chroma['sr'], 
                                 vmin=0, vmax=1,  
                                 cmap = plt.get_cmap('Purples_r'))

plt.savefig("songVizOrdered.png")

# %%
from palettable.cartocolors.sequential import Sunset_7_r
from palettable.colorbrewer.sequential import GnBu_9_r

_e_chroma = e_chromas.copy()
_t_chroma = t_chromas.copy()
shuffle(_e_chroma)
shuffle(_t_chroma)

fig, ax = plt.subplots(nrows=3, ncols=3, sharex=True, sharey=True, figsize=(12, 6))
plt.subplots_adjust(hspace=0.15,wspace=0.1)
fig.text(0.5, 0.04, 'Time', ha='center')
fig.text(0.04, 0.5, 'Pitch Class', va='center', rotation='vertical')

ax1 = plt.subplot(2,2,1)
c = _t_chroma.pop()
librosa.display.specshow(c['chroma'], sr=c['sr'],
                         vmin=0, vmax=1, 
                         x_axis='time', y_axis='chroma',
                         cmap =  plt.get_cmap('RdPu_r'))
xticks = ax1.xaxis.get_major_ticks()
xticks[1].label1.set_visible(False)
xticks[2].label1.set_visible(False)
xticks[3].label1.set_visible(False)
xticks[4].label1.set_visible(False)
xticks[5].label1.set_visible(False)
ax1.set_xlabel("")
ax1.set_ylabel("")
ax1.yaxis.tick_right()

ax2 = plt.subplot(2,2,2)    
c = _e_chroma.pop()
librosa.display.specshow(c['chroma'], sr=c['sr'], 
                         x_axis='time', y_axis='chroma',
                               vmin=0, vmax=1,
                        cmap = plt.get_cmap('Purples_r'))


ax2.set_yticklabels([])
ax2.set_xticklabels([])
ax2.set_xlabel("")
ax2.set_ylabel("")

ax3 = plt.subplot(2,2,3)
c = _t_chroma.pop()
librosa.display.specshow(c['chroma'], sr=c['sr'], 
                         x_axis='time', y_axis='chroma',
                               vmin=0, vmax=1,
                        cmap = plt.get_cmap('Purples_r'))

ax3.set_yticklabels([])
ax3.set_xticklabels([])
ax3.set_xlabel("")
ax3.set_ylabel("")
ax3.yaxis.tick_right()



ax4 = plt.subplot(2,2,4)    
c = _e_chroma.pop()
librosa.display.specshow(c['chroma'], sr=c['sr'],
                         vmin=0, vmax=1, 
                         x_axis='time', y_axis='chroma',
                         cmap =  plt.get_cmap('RdPu_r'))


xticks = ax4.xaxis.get_major_ticks()
xticks[1].label1.set_visible(False)
xticks[2].label1.set_visible(False)
xticks[3].label1.set_visible(False)
xticks[4].label1.set_visible(False)
xticks[5].label1.set_visible(False)
ax4.set_xlabel("")
ax4.set_ylabel("")


plt.savefig("zoomedSongs.png")

# %%
from palettable.cartocolors.sequential import Sunset_7_r
from palettable.colorbrewer.sequential import GnBu_9_r

plt.figure(figsize=(14,12))
gs1 = gridspec.GridSpec(6, 7)
gs1.update(wspace=0.0, hspace=0.0)
gs_ix = 0

all_indices = set(list(range(0,42)))
e_indices = set([0,1,5,7,8,10,12,13,15,17,18,23,24,30,37])
t_indices = all_indices - e_indices

_e_chroma = e_chromas.copy()
_t_chroma = t_chromas.copy()


shuffle(_e_chroma)
shuffle(_t_chroma)
for e in e_indices:
    plt.subplot(gs1[e])
    c = _e_chroma.pop()
    librosa.display.specshow(c['chroma'], sr=c['chroma'], 
                         vmin=0, vmax=1,  cmap =plt.get_cmap('Purples_r'))
    
for t in t_indices:
    plt.subplot(gs1[t])
    c = _t_chroma.pop()
    librosa.display.specshow(c['chroma'], sr=c['sr'], 
                         vmin=0, vmax=1,  
                             cmap =plt.get_cmap('RdPu_r'))

# %% [markdown]
# My own tracks

# %%
url = "https://api.spotify.com/v1/me/tracks"
headers = {'Authorization': "Bearer {}".format(TOKEN)}
r = requests.get(url, headers=headers)
parsed = json.loads(r.text)
count_songs = parsed["total"]
print("Total number of songs: {}".format(count_songs))
# Out:
# Total number of songs: 849

# %%
all_songs = []

for i in range(int(ceil(count_songs/50.0))):
    offset = 50*i
    url = "https://api.spotify.com/v1/me/tracks?limit=50&offset={}".format(offset)
    headers = {'Authorization': "Bearer {}".format(TOKEN)}
    r = requests.get(url, headers=headers)
    parsed = json.loads(r.text)
    
    all_songs.extend(parsed["items"])
    
print("Number of gathered songs: {}".format(len(all_songs)))
# Out:
# Number of gathered songs: 849

# %%
song_ids = []

for song in all_songs:
    _id = song['track']['id']
    song_ids.append(_id)
print("Number of ids gathered: {}".format(len(all_songs)))
# Out:
# Number of ids gathered: 848

# %%
all_songs[0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
song_features_by_id = {}

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

s = requests.Session()
retries = Retry(total=300, backoff_factor=1, 
                status_forcelist=[502,503,504,429])
s.mount('https://', HTTPAdapter(max_retries=retries))

for song_id in song_ids:
    url = "https://api.spotify.com/v1/audio-features/{}".format(song_id)
    headers = {'Authorization': "Bearer {}".format(TOKEN)}
    r = s.get(url, headers=headers)
    
    parsed = json.loads(r.text)
    
    song_info = parsed

    
    try:
        a = song_info["type"]
    except:
        print(parsed)
        
    song_features_by_id[song_id] = song_info

# %%
print(len(song_features_by_id))
# Out:
# 838

# %% [markdown]
# I want to get a better sense of the distribution of the following features in my playlist.
#
# Do I listen to danceable songs?
# Is the playlist a high energy or low energy playlist?

# %%
song_features_by_id['1Qf2f55yIV8bMxWmEpJoTb']
# Out:
# {'danceability': 0.656,
#  'energy': 0.602,
#  'key': 9,
#  'loudness': -8.11,
#  'mode': 0,
#  'speechiness': 0.0301,
#  'acousticness': 0.111,
#  'instrumentalness': 7.28e-05,
#  'liveness': 0.112,
#  'valence': 0.721,
#  'tempo': 105.874,
#  'type': 'audio_features',
#  'id': '1Qf2f55yIV8bMxWmEpJoTb',
#  'uri': 'spotify:track:1Qf2f55yIV8bMxWmEpJoTb',
#  'track_href': 'https://api.spotify.com/v1/tracks/1Qf2f55yIV8bMxWmEpJoTb',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Qf2f55yIV8bMxWmEpJoTb',
#  'duration_ms': 191213,
#  'time_signature': 4}

# %%
danceability =  []
energy = []
acousticness = []
valence = []
speechiness = []
liveness = []    

for song_id in song_features_by_id:
    d = song_features_by_id[song_id]['danceability']
    e = song_features_by_id[song_id]['energy']
    a = song_features_by_id[song_id]['acousticness']
    v = song_features_by_id[song_id]['valence']
    s = song_features_by_id[song_id]['speechiness']
    l = song_features_by_id[song_id]['liveness']
    speechiness.append(s)
    valence.append(v)
    acousticness.append(a)    
    energy.append(e)
    danceability.append(d)
    liveness.append(l)

sns.set(color_codes=True)
f, axes = plt.subplots(2, 3, figsize=(9,9), sharey=True)   


ax = sns.distplot(danceability, ax=axes[0,0])
ax.set_title("danceability of Songs")

ax = sns.distplot(energy, ax=axes[0,1])
ax.set_title("energy of Songs")

ax = sns.distplot(acousticness, ax=axes[0,2])
ax.set_title("acousticness of Songs")

ax = sns.distplot(valence, ax=axes[1,0])
ax.set_title("valence of Songs")

ax = sns.distplot(speechiness, ax=axes[1,1])
ax.set_title("speechiness of Songs")

ax = sns.distplot(liveness, ax=axes[1,2])
ax.set_title("liveness of Songs")
# Out:
# /home/lildreamz/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'liveness of Songs')

# %%
import pandas as pd

# %%
song_features_df = pd.DataFrame(
    { 'Danceability': danceability,
      'Energy': energy,
      'Acousticness': acousticness,
      'Valence': valence,
      'Speechiness': speechiness,
      'liveness': liveness
    })

# %% [markdown]
# The pairplot show that there might be a relationship between
# Valence and Danceability
# Acousticness and Energy

# %%
sns.pairplot(song_features_df)

# %%
sns.boxplot(x="variable", y="value", data=pd.melt(song_features_df))

# %%
song_add_date = []

for song in all_songs:
    timestamp = song['added_at']
    song_add_date.append(timestamp)

# %%
from datetime import datetime

song_timestamp = [datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ').date() for date in song_add_date]

# %%
song_features_df = song_features_df.assign(Timestamp=song_timestamp)
song_features_df['Timestamp'] = pd.to_datetime(song_features_df['Timestamp'])

# %%
song_features_df.head()
# Out:
#    Danceability  Energy  Acousticness  Valence  Speechiness  liveness  \
# 0         0.772   0.623        0.1480    0.692       0.3540     0.408
# 1         0.599   0.258        0.8660    0.448       0.0310     0.260
# 2         0.592   0.581        0.1410    0.286       0.0233     0.368
# 3         0.661   0.733        0.5740    0.753       0.0314     0.750
# 4         0.664   0.672        0.0173    0.841       0.1050     0.130
#
#     Timestamp
# 0  2019-02-28
# 1  2019-02-28
# 2  2019-02-28
# 3  2019-02-27
# 4  2019-02-27

# %%
years = song_features_df.Timestamp.apply(lambda x: x.strftime('%y'))

sns.set(color_codes=True)
f, axes = plt.subplots(2, 3, figsize=(12,8), sharex=True)

ax = sns.boxplot(years, song_features_df.Danceability,ax=axes[0,0])

ax = sns.boxplot(years, song_features_df.Energy,ax=axes[0,1])

ax = sns.boxplot(years, song_features_df.Acousticness,ax=axes[0,2])

ax = sns.boxplot(years, song_features_df.Valence,ax=axes[1,0])

ax = sns.boxplot(years, song_features_df.Speechiness,ax=axes[1,1])

ax = sns.boxplot(years, song_features_df.liveness,ax=axes[1,2])

# %% [markdown]
# Experimental Im going to bin track to an album and see whats good if not I will just append the genres to a different dataframe.

# %%
artist_ids = set()

for song in all_songs:
    artists = song['track']['artists']
    for artist in artists:
        artist_ids.add(artist['id'])
    
print("Number of artists: {}".format(len(artist_ids)))
# Out:
# Number of artists: 233

# %%
artist_info_by_id = {}

s = requests.Session()
retries = Retry(total=3000, backoff_factor=1, status_forcelist=[ 502, 503, 504, 429 ])
s.mount('https://', HTTPAdapter(max_retries=retries))

for artist_id in artist_ids:
    url = "https://api.spotify.com/v1/artists/{}".format(artist_id)
    headers = {'Authorization': "Bearer {}".format(TOKEN)}
    r = s.get(url, headers=headers)

    #TODO: check for error apart from dumb retries?

    parsed = json.loads(r.text)    

    artist_info = parsed

    #TODO: sanity checks?
    try:
        a = artist_info["genres"]
    except:
        print("Entry seems wrong. Fix it:")
        print(artist_info)
        break

    artist_info_by_id[artist_id] = artist_info

# %%
song_genres_based_on_artist = []
for song in all_songs:
    genres = []
    artists = song['track']['artists']
    for artist in artists:
        _id = artist['id']
        genres.extend(artist_info_by_id[_id]['genres'])
    song_genres_based_on_artist.append(genres)
# Out:
# ['gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'atl hip hop', 'gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# ['hyphy']
# []
# ['cali rap', 'gangster rap', 'hip hop', 'hyphy', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast rap', 'west coast trap', 'hyphy', 'west coast rap']
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['gqom']
# ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop']
# ['hip hop', 'irish hip hop', 'rap', 'uk alternative hip hop', 'underground hip hop', 'minneapolis indie']
# ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop', 'indie pop', 'indie rock', 'modern alternative rock', 'modern rock']
# ['chicago rap', 'underground hip hop']
# ['cali rap', 'gangster rap', 'hyphy', 'west coast rap', 'west coast trap']
# ['cali rap', 'detroit trap', 'west coast trap']
# ['freak folk', 'indie garage rock', 'neo-psychedelic', 'preverb']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic', 'vapor soul']
# ['experimental pop', 'indie garage rock', 'neo-psychedelic', 'preverb']
# ['funk']
# ['funk']
# ['funk']
# ['neo r&b']
# ['funk', 'garage rock', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'punk blues']
# ['alternative r&b', 'escape room']
# ['memphis hip hop']
# ['alternative r&b', 'bedroom pop', 'indie r&b', 'modern rock', 'vapor soul']
# ['alternative r&b', 'escape room', 'indie r&b', 'neo soul', 'r&b']
# ['canadian contemporary r&b', 'pop', 'alternative hip hop', 'canadian modern jazz', 'dark jazz', 'escape room', 'funk', 'hip hop', 'canadian hip hop', 'deep underground hip hop', 'trap soul', 'underground hip hop']
# ['chillwave', 'indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic', 'vapor soul']
# ['album rock', 'blues-rock', 'classic rock', 'hard rock', 'metal', 'psychedelic rock', 'rock']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['freak folk', 'indie garage rock', 'neo-psychedelic', 'preverb']
# ['australian garage punk', 'garage rock', 'indie garage rock', 'indie punk', 'preverb']
# ['guadalajara indie', 'latin alternative', 'latin rock', 'mexican indie', 'mexican rock', 'rock en espanol']
# ['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']
# ['deep house', 'float house', 'indie jazz', 'lo-fi house', 'tech house']
# []
# ['deep house', 'float house', 'indie jazz', 'lo-fi house', 'tech house']
# ['alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'rap', 'underground hip hop']
# ['boy band', 'hip hop', 'rap']
# ['alternative dance', 'alternative r&b', 'art pop', 'chillwave', 'freak folk', 'indie pop', 'indietronica', 'modern rock', 'new rave', 'nu gaze']
# ['alternative dance', 'alternative r&b', 'art pop', 'chillwave', 'freak folk', 'indie pop', 'indietronica', 'modern rock', 'new rave', 'nu gaze']
# ['indie psych-rock', 'indietronica', 'vapor soul']
# ['neo r&b', 'alternative r&b', 'indie r&b', 'trap soul']
# ['uk contemporary r&b']
# ['alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'rap', 'underground hip hop']
# ['alternative r&b', 'indie garage rock', 'indie r&b']
# ['alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'rap', 'underground hip hop']
# ['gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'alternative hip hop', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# ['hyphy', 'west coast rap']
# ['moombahton', 'abstract beats', 'alternative r&b', 'indie r&b', 'neo r&b', 'trap soul', 'underground hip hop', 'vapor twitch', 'indie r&b']
# ['alternative hip hop', 'escape room', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'alternative hip hop', 'funk', 'hip hop', 'turntablism', 'alternative hip hop', 'hip hop', 'pop rap', 'rap', 'underground hip hop', 'alternative hip hop', 'escape room', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop', 'gqom', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['alternative r&b', 'indie r&b']
# ['jazz rap']
# []
# ['alternative r&b', 'chicago rap', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['afrobeat', 'funk', 'indie jazz', 'nu jazz', 'nz reggae', 'soul', 'trip hop']
# ['indie pop', 'indie poptimism', 'indie psych-rock', 'indietronica', 'la indie', 'modern rock', 'vapor soul']
# ['deep house', 'future garage', 'indie jazz', 'indietronica', 'new rave', 'ninja', 'nu jazz', 'south african alternative']
# ['uk contemporary r&b']
# ['bedroom pop', 'indie garage rock']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['funk', 'neo-psychedelic']
# ['alternative r&b', 'bedroom pop']
# ['afrobeat', 'afropop', 'funk', 'soul', 'world']
# ['future funk', 'hardvapour', 'vapor twitch', 'vaporwave', 'wave']
# []
# ['atl hip hop', 'dirty south rap', 'pop rap', 'southern hip hop']
# []
# ['alternative r&b', 'indie jazz', 'neo r&b', 'contemporary jazz', 'contemporary post-bop', 'indie jazz', 'jazz', 'jazz fusion', 'neo r&b', 'neo soul', 'hip hop']
# ['chillwave', 'indietronica', 'kiwi rock', 'neo-psychedelic']
# ['downtempo']
# ['funk', 'instrumental funk']
# ['australian garage punk', 'australian reggae fusion']
# ['dub', 'reggae', 'roots reggae', 'ska']
# []
# ['afro psych', 'doom metal', 'neo-psychedelic', 'sludge metal', 'stoner metal', 'stoner rock', 'zambian pop']
# ['funk']
# ['australian reggae fusion']
# []
# ['indie psych-rock', 'vapor soul']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative r&b', 'indie jazz']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'deep pop r&b']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'portland hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative hip hop', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'neo soul']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative r&b', 'chicago rap', 'hip hop', 'indie r&b', 'neo soul', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'underground hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'r&b', 'rap', 'trap soul', 'underground hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative r&b', 'chicago rap', 'hip hop', 'indie r&b', 'neo soul', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'underground hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative hip hop', 'alternative r&b', 'escape room', 'hip hop', 'nc hip hop', 'pop rap', 'southern hip hop', 'trap queen', 'underground hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'deep pop r&b']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative hip hop', 'conscious hip hop', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'pop rap', 'southern hip hop']
# ['escape room', 'hip hop', 'pop rap', 'rap', 'gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# ['modern blues']
# ['alternative r&b', 'indie r&b', 'neo r&b', 'trap soul']
# []
# ['alternative r&b', 'indie psych-rock', 'vapor soul']
# ['alternative dance', 'alternative r&b', 'art pop', 'chillwave', 'downtempo', 'electronic', 'electropop', 'escape room', 'gothenburg indie', 'indietronica', 'new rave', 'swedish electropop', 'swedish synthpop', 'trip hop']
# ['alternative r&b', 'indie r&b', 'canadian contemporary r&b', 'pop', 'chillwave', 'freak folk', 'indie pop', 'indie rock', 'indietronica', 'modern rock', 'neo-psychedelic', 'new rave', 'portland hip hop']
# ['alternative r&b', 'art pop', 'chillwave', 'electropop', 'escape room', 'indie r&b', 'indietronica', 'metropopolis']
# ['alternative r&b', 'colombian pop', 'pop', 'hip hop', 'pop rap', 'rap', 'funk', 'jazz funk', 'p funk', 'quiet storm', 'soul']
# ['chillwave', 'freak folk', 'indie pop', 'indie rock', 'indietronica', 'modern rock', 'neo-psychedelic', 'new rave', 'portland hip hop']
# ['afrobeat', 'funk', 'jazz funk', 'soul', 'soul jazz']
# ['traditional soul']
# ['bossa nova', 'brazilian soul', 'mpb', 'pagode', 'samba']
# ['jazz funk']
# []
# ['classic soul', 'disco', 'funk', 'motown', 'quiet storm', 'soul', 'southern soul']
# ['album rock', 'classic canadian rock', 'classic rock', 'mellow gold', 'permanent wave', 'psychedelic rock', 'rock', 'roots rock', 'singer-songwriter']
# ['alternative rock', 'chillwave', 'experimental pop', 'folk-pop', 'freak folk', 'garage rock', 'indie folk', 'indie garage rock', 'indie pop', 'indie rock', 'indietronica', 'lo-fi', 'modern rock', 'neo-psychedelic', 'new rave', 'noise pop']
# ['abstract hip hop', 'alternative hip hop', 'escape room', 'alternative hip hop', 'escape room', 'milwaukee hip hop', 'escape room', 'hip hop', 'pop rap', 'rap']
# ['neo-psychedelic']
# ['disco', 'funk', 'post-disco', 'quiet storm']
# []
# ['underground hip hop']
# ['disco', 'funk', 'jazz funk', 'motown', 'post-disco', 'quiet storm', 'soul', 'urban contemporary']
# ['acid jazz', 'afrobeat', 'disco', 'funk', 'indie jazz', 'jazz funk', 'jazz vibraphone', 'post-disco', 'quiet storm', 'soul', 'soul jazz']
# ['classic soul', 'disco', 'funk', 'jazz funk', 'post-disco', 'quiet storm', 'soul', 'soul jazz']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['australian indie', 'australian psych', 'neo-psychedelic']
# ['austindie', 'chamber psych', 'freak folk', 'funk', 'garage rock', 'indie rock', 'modern rock', 'neo-psychedelic']
# ['chillhop', 'vapor twitch', 'alternative r&b', 'indie r&b']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['chillwave', 'dream pop', 'freak folk', 'french shoegaze', 'indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic', 'noise pop', 'nu gaze', 'preverb', 'shiver pop']
# ['album rock', 'art rock', 'classic rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock']
# ['chillhop', 'vapor twitch']
# ['chillhop', 'vapor twitch']
# ['chillhop', 'vapor twitch']
# ['chillhop', 'vapor twitch']
# ['chillhop', 'vapor twitch']
# ['chillhop', 'vapor twitch']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch', 'alternative r&b', 'aussietronica', 'electropop', 'indie r&b', 'vapor soul']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['uk contemporary r&b']
# ['uk contemporary r&b']
# ['uk contemporary r&b']
# ['uk contemporary r&b']
# ['uk contemporary r&b']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'cali rap', 'gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'dance pop', 'east coast hip hop', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'alternative r&b', 'cali rap', 'rap', 'trap soul', 'underground hip hop']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'dancehall']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'deep pop r&b', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'alternative r&b', 'dance pop', 'deep pop r&b', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music', 'urban contemporary']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'atl hip hop']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'alternative r&b', 'british soul', 'dance pop', 'deep pop r&b', 'hip pop', 'indie r&b', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap', 'canadian hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'trap soul', 'underground hip hop', 'cali rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'west coast trap']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'funk', 'p funk', 'soul', 'hip hop']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'neo r&b', 'neo soul', 'urban contemporary', 'alternative r&b', 'escape room', 'g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'neo r&b', 'neo soul', 'urban contemporary', 'alternative r&b', 'escape room', 'hip hop']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'quiet storm', 'urban contemporary']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap', 'alternative hip hop', 'alternative r&b', 'escape room', 'hip hop', 'nc hip hop', 'pop rap', 'southern hip hop', 'trap queen', 'underground hip hop']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'dance pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'art pop', 'alternative dance', 'art pop', 'chillwave', 'dream pop', 'electropop', 'experimental pop', 'folk-pop', 'indie pop', 'indie psych-rock', 'indie rock', 'indie surf', 'indietronica', 'modern rock', 'new rave', 'nu gaze', 'shimmer pop']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'atl hip hop', 'dance pop', 'girl group', 'hip pop', 'maskandi', 'new jack swing', 'pop', 'r&b', 'urban contemporary']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap', 'alternative r&b', 'dance pop', 'deep pop r&b', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# []
# []
# []
# []
# []
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# ['alternative country', 'new americana', 'roots rock']
# []
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['jam band']
# ['jam band']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['austindie']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['blues-rock', 'classic rock', 'rock']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['blues', 'blues-rock', 'classic rock', 'classic soul', 'electric blues', 'folk rock', 'funk', 'jazz blues', 'louisiana blues', 'modern blues', 'new orleans blues', 'piano blues', 'psychedelic rock', 'roots rock', 'soul']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# ...
# ['contemporary jazz', 'contemporary post-bop']
# ['contemporary jazz', 'contemporary post-bop']
# ['alternative hip hop', 'escape room', 'hip hop', 'underground hip hop']
# []
# []
# []
# []
# []
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'jazz double bass', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'jazz double bass', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'jazz double bass', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'jazz double bass', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride', 'jazz double bass', 'avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']

# %%
for artist_id in artist_ids:
    print(artist_info_by_id[artist_id]['genres'])
# Out:
# ['funk']
# ['alternative r&b', 'cali rap', 'rap', 'trap soul', 'underground hip hop']
# ['avant-garde jazz', 'bebop', 'contemporary jazz', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'indonesian jazz', 'jazz', 'jazz funk', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# []
# []
# ['alternative dance', 'alternative r&b', 'art pop', 'chillwave', 'downtempo', 'electronic', 'electropop', 'escape room', 'gothenburg indie', 'indietronica', 'new rave', 'swedish electropop', 'swedish synthpop', 'trip hop']
# ['alternative r&b', 'bass music', 'chillwave', 'future garage', 'vapor twitch', 'wonky']
# []
# []
# ['alternative rock', 'art rock', 'dance rock', 'experimental', 'experimental rock', 'garage rock', 'new romantic', 'new wave', 'post-punk', 'punk', 'rock', 'synthpop', 'uk post-punk', 'zolo']
# ['classic soul', 'disco', 'funk', 'jazz funk', 'post-disco', 'quiet storm', 'soul', 'soul jazz']
# ['alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'rap', 'underground hip hop']
# ['neo r&b']
# ['alternative hip hop', 'escape room', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# ['afrobeat', 'funk', 'indie jazz', 'nu jazz', 'nz reggae', 'soul', 'trip hop']
# ['canadian hip hop', 'deep underground hip hop', 'trap soul', 'underground hip hop']
# ['disco', 'funk', 'post-disco', 'quiet storm']
# ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul']
# ['hyphy', 'west coast rap']
# ['canadian contemporary r&b', 'pop']
# ['afrobeat', 'funk', 'jazz funk', 'soul', 'soul jazz']
# ['chicago rap', 'underground hip hop']
# ['dancehall']
# ['chillwave', 'indietronica', 'kiwi rock', 'neo-psychedelic']
# ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb']
# ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch']
# ['hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['afrobeat', 'funk', 'jazz funk', 'new orleans funk', 'soul jazz']
# ['jazz rap']
# ['cali rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop', 'west coast trap']
# []
# ['chillwave', 'indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic', 'vapor soul']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['alternative r&b', 'indie jazz']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'hard rock', 'mellow gold', 'rock', 'southern rock']
# ['australian garage punk', 'australian reggae fusion']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz trumpet', 'vocal jazz']
# ['hip hop']
# ['alternative hip hop', 'canadian modern jazz', 'dark jazz', 'escape room', 'funk', 'hip hop']
# ['album rock', 'blues-rock', 'classic rock', 'country rock', 'electric blues', 'folk rock', 'hard rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'soft rock', 'southern rock']
# []
# ['acid jazz', 'afrobeat', 'disco', 'funk', 'indie jazz', 'jazz funk', 'jazz vibraphone', 'post-disco', 'quiet storm', 'soul', 'soul jazz']
# ['alternative rock', 'art pop', 'baltimore indie', 'chamber pop', 'chillwave', 'dance-punk', 'dream pop', 'experimental pop', 'experimental rock', 'folk-pop', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'indietronica', 'lo-fi', 'modern rock', 'new rave', 'noise pop', 'noise rock', 'nu gaze']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz double bass', 'jazz electric bass', 'jazz fusion']
# []
# ['g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['chillwave', 'freak folk', 'indie pop', 'indie rock', 'indietronica', 'modern rock', 'neo-psychedelic', 'new rave', 'portland hip hop']
# ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# []
# ['album rock', 'art rock', 'classic rock', 'mellow gold', 'progressive rock', 'rock', 'soft rock', 'symphonic rock']
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz drums', 'soul jazz']
# ['dance pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary']
# ['alternative r&b', 'colombian pop', 'pop']
# ['alternative r&b', 'escape room', 'indie r&b', 'neo soul', 'r&b']
# ['conscious hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast trap']
# ['classic rock', 'permanent wave', 'punk', 'rock', 'skate punk']
# ['alternative r&b', 'british soul', 'dance pop', 'deep pop r&b', 'hip pop', 'indie r&b', 'neo soul', 'new jack swing', 'quiet storm', 'r&b', 'urban contemporary']
# ['downtempo']
# ['neo r&b']
# ['alternative r&b', 'indie r&b', 'neo r&b', 'trap soul']
# ['modern blues']
# ['album rock', 'blues-rock', 'classic rock', 'hard rock', 'metal', 'psychedelic rock', 'rock']
# ['alternative hip hop', 'funk', 'hip hop', 'turntablism']
# []
# []
# ['funk', 'p funk', 'soul']
# ['jam band']
# ['future funk', 'hardvapour', 'vapor twitch', 'vaporwave', 'wave']
# []
# ['hip hop', 'pop rap', 'rap']
# ['hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# ['funk', 'jazz funk', 'p funk', 'quiet storm', 'soul']
# ['abstract beats', 'alternative r&b', 'indie r&b', 'neo r&b', 'trap soul', 'underground hip hop', 'vapor twitch']
# ['jazz double bass']
# ['indie psych-rock', 'indietronica', 'vapor soul']
# ['hyphy']
# ['australian indie', 'australian psych', 'neo-psychedelic']
# ['hip hop', 'irish hip hop', 'rap', 'uk alternative hip hop', 'underground hip hop']
# ['australian reggae fusion']
# ['dub', 'reggae', 'roots reggae', 'ska']
# ['alternative r&b', 'indie r&b', 'trap soul']
# ['alternative r&b', 'bedroom pop', 'indie r&b', 'modern rock', 'vapor soul']
# ['alternative r&b', 'indie garage rock', 'indie r&b']
# ['dance pop', 'east coast hip hop', 'hip hop', 'hip pop', 'pop rap', 'r&b', 'rap']
# ['alternative r&b', 'bedroom pop']
# []
# ['alternative hip hop', 'escape room', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['bossa nova', 'brazilian soul', 'mpb', 'pagode', 'samba']
# []
# ['chillwave', 'dream pop', 'freak folk', 'french shoegaze', 'indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic', 'noise pop', 'nu gaze', 'preverb', 'shiver pop']
# ['moombahton']
# ['experimental pop', 'indie garage rock', 'neo-psychedelic', 'preverb']
# ['alternative hip hop', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'neo soul']
# ['alternative metal', 'alternative rock', 'el paso indie', 'funk rock', 'garage rock', 'modern rock', 'rock']
# ['atl hip hop']
# ['alternative r&b', 'chicago rap', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['alternative r&b', 'escape room']
# ['deep pop r&b']
# ['alternative r&b', 'dance pop', 'deep pop r&b', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'urban contemporary']
# ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
# []
# ['bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz saxophone', 'vocal jazz']
# ['alternative dance', 'art pop', 'chillwave', 'dream pop', 'electropop', 'experimental pop', 'folk-pop', 'indie pop', 'indie psych-rock', 'indie rock', 'indie surf', 'indietronica', 'modern rock', 'new rave', 'nu gaze', 'shimmer pop']
# ['album rock', 'art rock', 'canadian metal', 'classic canadian rock', 'classic rock', 'hard rock', 'metal', 'progressive metal', 'progressive rock', 'rock']
# ['memphis hip hop']
# ['cali rap', 'gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# ['atl hip hop', 'gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']
# []
# ['funk']
# ['alternative hip hop', 'conscious hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'underground hip hop']
# ['alternative hip hop', 'conscious hip hop', 'east coast hip hop', 'hardcore hip hop', 'hip hop', 'pop rap', 'southern hip hop']
# ['canadian hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'trap soul', 'underground hip hop']
# ['australian garage punk', 'garage rock', 'indie garage rock', 'indie punk', 'preverb']
# []
# ['afro psych', 'doom metal', 'neo-psychedelic', 'sludge metal', 'stoner metal', 'stoner rock', 'zambian pop']
# ['chillhop', 'vapor twitch']
# ['alternative metal', 'groove metal', 'hard rock', 'metal', 'nu metal', 'rock', 'wrestling']
# ['cali rap', 'gangster rap', 'hyphy', 'west coast rap', 'west coast trap']
# []
# ['avant-garde jazz', 'bebop', 'big band', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz', 'stride', 'vocal jazz']
# ['deep house', 'future garage', 'indie jazz', 'indietronica', 'new rave', 'ninja', 'nu jazz', 'south african alternative']
# ['austindie']
# ['deep pop r&b', 'west coast trap']
# ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic']
# ['album rock', 'folk rock', 'mellow gold', 'rock', 'soft rock']
# ['kentucky indie']
# ['g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# ['alternative r&b', 'escape room']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'vocal jazz']
# ['jazz funk']
# []
# ['neo r&b', 'neo soul', 'urban contemporary']
# ['cali rap', 'detroit trap', 'west coast trap']
# []
# ['album rock', 'classic canadian rock', 'classic rock', 'mellow gold', 'permanent wave', 'psychedelic rock', 'rock', 'roots rock', 'singer-songwriter']
# ['uk contemporary r&b']
# ['alternative r&b', 'indie r&b']
# ['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul']
# ['guadalajara indie', 'latin alternative', 'latin rock', 'mexican indie', 'mexican rock', 'rock en espanol']
# []
# ['alternative r&b', 'aussietronica', 'electropop', 'indie r&b', 'vapor soul']
# ['alternative rock', 'boston rock', 'garage rock', 'indie rock', 'modern rock', 'new wave', 'noise pop', 'permanent wave', 'rock']
# ['afrobeat', 'afropop', 'funk', 'soul', 'world']
# ['blues-rock', 'classic rock', 'folk rock', 'jam band', 'mellow gold', 'psychedelic rock', 'rock', 'roots rock', 'southern rock']
# ['australian garage punk', 'australian psych', 'neo-psychedelic']
# ['alternative hip hop', 'escape room', 'hip hop', 'underground hip hop']
# ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap']
# []
# ['freak folk', 'indie garage rock', 'neo-psychedelic', 'preverb']
# ['funk', 'neo-psychedelic']
# ['alternative dance', 'alternative r&b', 'art pop', 'chillwave', 'freak folk', 'indie pop', 'indietronica', 'modern rock', 'new rave', 'nu gaze']
# ['deep house', 'float house', 'indie jazz', 'lo-fi house', 'tech house']
# ['traditional soul']
# []
# ['gqom']
# ['funk', 'garage rock', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'punk blues']
# ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap']
# ['bedroom pop', 'indie garage rock']
# ['alternative r&b', 'indie r&b']
# ['alternative country', 'new americana', 'roots rock']
# []
# []
# ['abstract hip hop', 'alternative hip hop', 'escape room']
# ['contemporary jazz', 'indie jazz']
# ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop']
# ['uk contemporary r&b']
# ['art pop']
# ['cali rap', 'gangster rap', 'hip hop', 'hyphy', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'west coast rap', 'west coast trap']
# ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock']
# []
# ['indie r&b']
# []
# ['british soul', 'ninja']
# ['deep new americana', 'modern blues rock']
# ['alternative r&b', 'dance pop', 'deep pop r&b', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music', 'urban contemporary']
# ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano']
# ['alternative r&b', 'chicago rap', 'hip hop', 'indie r&b', 'neo soul', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'underground hip hop']
# ['album rock', 'art rock', 'classic rock', 'folk rock', 'mellow gold', 'psychedelic rock', 'rock']
# ['bow pop', 'compositional ambient']
# ['alternative r&b', 'hip hop', 'indie r&b', 'pop rap', 'r&b', 'rap', 'trap soul', 'underground hip hop']
# ['alternative hip hop', 'escape room', 'milwaukee hip hop']
# []
# ['bebop', 'contemporary post-bop', 'cool jazz', 'hard bop', 'jazz', 'jazz piano', 'soul jazz', 'stride']
# []
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'jazz saxophone', 'soul jazz']
# ['funk']
# ['gauze pop']
# ['boy band', 'hip hop', 'rap']
# ['blues', 'blues-rock', 'classic rock', 'classic soul', 'electric blues', 'folk rock', 'funk', 'jazz blues', 'louisiana blues', 'modern blues', 'new orleans blues', 'piano blues', 'psychedelic rock', 'roots rock', 'soul']
# ['atl hip hop', 'dance pop', 'girl group', 'hip pop', 'maskandi', 'new jack swing', 'pop', 'r&b', 'urban contemporary']
# ['alternative r&b', 'art pop', 'chillwave', 'electropop', 'escape room', 'indie r&b', 'indietronica', 'metropopolis']
# []
# ['indie pop', 'indie rock', 'modern alternative rock', 'modern rock']
# ['minneapolis indie']
# []
# ['alternative hip hop', 'alternative r&b', 'escape room', 'hip hop', 'nc hip hop', 'pop rap', 'southern hip hop', 'trap queen', 'underground hip hop']
# ['indie psych-rock', 'vapor soul']
# ['escape room', 'hip hop', 'pop rap', 'rap']
# ['contemporary jazz', 'contemporary post-bop']
# []
# ['portland hip hop']
# ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop']
# []
# ['underground hip hop']
# ['indie pop', 'indie poptimism', 'indie psych-rock', 'indietronica', 'la indie', 'modern rock', 'vapor soul']
# ['alternative r&b', 'indie jazz', 'neo r&b']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic']
# ['alternative hip hop', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['funk', 'instrumental funk']
# ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock']
# ['gangster rap', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# []
# []
# ['blues-rock', 'classic rock', 'rock']
# ['disco', 'funk', 'jazz funk', 'motown', 'post-disco', 'quiet storm', 'soul', 'urban contemporary']
# ['alternative r&b', 'indie psych-rock', 'vapor soul']
# ['alternative rock', 'chillwave', 'experimental pop', 'folk-pop', 'freak folk', 'garage rock', 'indie folk', 'indie garage rock', 'indie pop', 'indie rock', 'indietronica', 'lo-fi', 'modern rock', 'neo-psychedelic', 'new rave', 'noise pop']
# ['atl hip hop', 'dirty south rap', 'pop rap', 'southern hip hop']
# ['austindie', 'chamber psych', 'freak folk', 'funk', 'garage rock', 'indie rock', 'modern rock', 'neo-psychedelic']
# ['quiet storm', 'urban contemporary']
# ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap']
# ['bebop', 'contemporary post-bop', 'cool jazz', 'funk', 'instrumental funk', 'jazz', 'jazz funk', 'jazz fusion', 'jazz piano', 'soul jazz']
# ['contemporary jazz', 'contemporary post-bop', 'indie jazz', 'jazz', 'jazz fusion', 'neo r&b', 'neo soul']
# ['classic soul', 'disco', 'funk', 'motown', 'quiet storm', 'soul', 'southern soul']
# ['alternative r&b', 'indie r&b']
# ['neo-psychedelic']
# ['doom metal', 'drone metal', 'post-doom metal', 'post-metal', 'psychedelic doom', 'retro metal', 'sludge metal', 'space rock', 'stoner metal', 'stoner rock']
# []
# ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap music', 'underground hip hop']
# []
# ['avant-garde jazz', 'bebop', 'contemporary post-bop', 'cool jazz', 'free improvisation', 'free jazz', 'hard bop', 'jazz', 'jazz fusion', 'soul jazz']
# ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'underground hip hop']
# ['indie garage rock', 'indie psych-rock', 'neo-psychedelic', 'vapor soul']

# %%
song_genres_based_on_artist
# Out:
# [['gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop',
#   'atl hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music'],
#  ['hyphy'],
#  [],
#  ['cali rap',
#   'gangster rap',
#   'hip hop',
#   'hyphy',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast rap',
#   'west coast trap',
#   'hyphy',
#   'west coast rap'],
#  ['atl hip hop', 'hip hop', 'pop rap', 'rap', 'underground hip hop'],
#  ['gqom'],
#  ['hip hop', 'pop rap', 'rap', 'trap music', 'underground hip hop'],
#  ['hip hop',
#   'irish hip hop',
#   'rap',
#   'uk alternative hip hop',
#   'underground hip hop',
#   'minneapolis indie'],
#  ['hip hop',
#   'pop rap',
#   'rap',
#   'trap music',
#   'underground hip hop',
#   'indie pop',
#   'indie rock',
#   'modern alternative rock',
#   'modern rock'],
#  ['chicago rap', 'underground hip hop'],
#  ['cali rap', 'gangster rap', 'hyphy', 'west coast rap', 'west coast trap'],
#  ['cali rap', 'detroit trap', 'west coast trap'],
#  ['freak folk', 'indie garage rock', 'neo-psychedelic', 'preverb'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic', 'vapor soul'],
#  ['experimental pop', 'indie garage rock', 'neo-psychedelic', 'preverb'],
#  ['funk'],
#  ['funk'],
#  ['funk'],
#  ['neo r&b'],
#  ['funk',
#   'garage rock',
#   'indie rock',
#   'modern alternative rock',
#   'modern blues rock',
#   'modern rock',
#   'punk blues'],
#  ['alternative r&b', 'escape room'],
#  ['memphis hip hop'],
#  ['alternative r&b', 'bedroom pop', 'indie r&b', 'modern rock', 'vapor soul'],
#  ['alternative r&b', 'escape room', 'indie r&b', 'neo soul', 'r&b'],
#  ['canadian contemporary r&b',
#   'pop',
#   'alternative hip hop',
#   'canadian modern jazz',
#   'dark jazz',
#   'escape room',
#   'funk',
#   'hip hop',
#   'canadian hip hop',
#   'deep underground hip hop',
#   'trap soul',
#   'underground hip hop'],
#  ['chillwave',
#   'indie garage rock',
#   'indie psych-rock',
#   'indietronica',
#   'neo-psychedelic',
#   'vapor soul'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'psychedelic rock',
#   'rock'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'indonesian jazz',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz'],
#  ['freak folk', 'indie garage rock', 'neo-psychedelic', 'preverb'],
#  ['australian garage punk',
#   'garage rock',
#   'indie garage rock',
#   'indie punk',
#   'preverb'],
#  ['guadalajara indie',
#   'latin alternative',
#   'latin rock',
#   'mexican indie',
#   'mexican rock',
#   'rock en espanol'],
#  ['classic soul', 'funk', 'motown', 'northern soul', 'quiet storm', 'soul'],
#  ['deep house', 'float house', 'indie jazz', 'lo-fi house', 'tech house'],
#  [],
#  ['deep house', 'float house', 'indie jazz', 'lo-fi house', 'tech house'],
#  ['alternative r&b',
#   'hip hop',
#   'indie r&b',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['boy band', 'hip hop', 'rap'],
#  ['alternative dance',
#   'alternative r&b',
#   'art pop',
#   'chillwave',
#   'freak folk',
#   'indie pop',
#   'indietronica',
#   'modern rock',
#   'new rave',
#   'nu gaze'],
#  ['alternative dance',
#   'alternative r&b',
#   'art pop',
#   'chillwave',
#   'freak folk',
#   'indie pop',
#   'indietronica',
#   'modern rock',
#   'new rave',
#   'nu gaze'],
#  ['indie psych-rock', 'indietronica', 'vapor soul'],
#  ['neo r&b', 'alternative r&b', 'indie r&b', 'trap soul'],
#  ['uk contemporary r&b'],
#  ['alternative r&b',
#   'hip hop',
#   'indie r&b',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['alternative r&b', 'indie garage rock', 'indie r&b'],
#  ['alternative r&b',
#   'hip hop',
#   'indie r&b',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop',
#   'alternative hip hop',
#   'conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'underground hip hop'],
#  ['hyphy', 'west coast rap'],
#  ['moombahton',
#   'abstract beats',
#   'alternative r&b',
#   'indie r&b',
#   'neo r&b',
#   'trap soul',
#   'underground hip hop',
#   'vapor twitch',
#   'indie r&b'],
#  ['alternative hip hop',
#   'escape room',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop',
#   'alternative hip hop',
#   'funk',
#   'hip hop',
#   'turntablism',
#   'alternative hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'underground hip hop',
#   'alternative hip hop',
#   'escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'underground hip hop',
#   'gqom',
#   'conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['alternative r&b', 'indie r&b'],
#  ['jazz rap'],
#  [],
#  ['alternative r&b',
#   'chicago rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['afrobeat',
#   'funk',
#   'indie jazz',
#   'nu jazz',
#   'nz reggae',
#   'soul',
#   'trip hop'],
#  ['indie pop',
#   'indie poptimism',
#   'indie psych-rock',
#   'indietronica',
#   'la indie',
#   'modern rock',
#   'vapor soul'],
#  ['deep house',
#   'future garage',
#   'indie jazz',
#   'indietronica',
#   'new rave',
#   'ninja',
#   'nu jazz',
#   'south african alternative'],
#  ['uk contemporary r&b'],
#  ['bedroom pop', 'indie garage rock'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['funk', 'neo-psychedelic'],
#  ['alternative r&b', 'bedroom pop'],
#  ['afrobeat', 'afropop', 'funk', 'soul', 'world'],
#  ['future funk', 'hardvapour', 'vapor twitch', 'vaporwave', 'wave'],
#  [],
#  ['atl hip hop', 'dirty south rap', 'pop rap', 'southern hip hop'],
#  [],
#  ['alternative r&b',
#   'indie jazz',
#   'neo r&b',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'indie jazz',
#   'jazz',
#   'jazz fusion',
#   'neo r&b',
#   'neo soul',
#   'hip hop'],
#  ['chillwave', 'indietronica', 'kiwi rock', 'neo-psychedelic'],
#  ['downtempo'],
#  ['funk', 'instrumental funk'],
#  ['australian garage punk', 'australian reggae fusion'],
#  ['dub', 'reggae', 'roots reggae', 'ska'],
#  [],
#  ['afro psych',
#   'doom metal',
#   'neo-psychedelic',
#   'sludge metal',
#   'stoner metal',
#   'stoner rock',
#   'zambian pop'],
#  ['funk'],
#  ['australian reggae fusion'],
#  [],
#  ['indie psych-rock', 'vapor soul'],
#  ['escape room', 'hip hop', 'pop rap', 'rap', 'alternative r&b', 'indie jazz'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap', 'deep pop r&b'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'g funk',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'g funk',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'portland hip hop'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'neo soul'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative r&b',
#   'chicago rap',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'underground hip hop'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative r&b',
#   'hip hop',
#   'indie r&b',
#   'pop rap',
#   'r&b',
#   'rap',
#   'trap soul',
#   'underground hip hop'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative r&b',
#   'chicago rap',
#   'hip hop',
#   'indie r&b',
#   'neo soul',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'underground hip hop'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative hip hop',
#   'alternative r&b',
#   'escape room',
#   'hip hop',
#   'nc hip hop',
#   'pop rap',
#   'southern hip hop',
#   'trap queen',
#   'underground hip hop'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'deep pop r&b'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room', 'hip hop', 'pop rap', 'rap'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'alternative hip hop',
#   'conscious hip hop',
#   'east coast hip hop',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'southern hip hop'],
#  ['escape room',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop'],
#  ['modern blues'],
#  ['alternative r&b', 'indie r&b', 'neo r&b', 'trap soul'],
#  [],
#  ['alternative r&b', 'indie psych-rock', 'vapor soul'],
#  ['alternative dance',
#   'alternative r&b',
#   'art pop',
#   'chillwave',
#   'downtempo',
#   'electronic',
#   'electropop',
#   'escape room',
#   'gothenburg indie',
#   'indietronica',
#   'new rave',
#   'swedish electropop',
#   'swedish synthpop',
#   'trip hop'],
#  ['alternative r&b',
#   'indie r&b',
#   'canadian contemporary r&b',
#   'pop',
#   'chillwave',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'neo-psychedelic',
#   'new rave',
#   'portland hip hop'],
#  ['alternative r&b',
#   'art pop',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie r&b',
#   'indietronica',
#   'metropopolis'],
#  ['alternative r&b',
#   'colombian pop',
#   'pop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'funk',
#   'jazz funk',
#   'p funk',
#   'quiet storm',
#   'soul'],
#  ['chillwave',
#   'freak folk',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'modern rock',
#   'neo-psychedelic',
#   'new rave',
#   'portland hip hop'],
#  ['afrobeat', 'funk', 'jazz funk', 'soul', 'soul jazz'],
#  ['traditional soul'],
#  ['bossa nova', 'brazilian soul', 'mpb', 'pagode', 'samba'],
#  ['jazz funk'],
#  [],
#  ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul'],
#  ['album rock',
#   'classic canadian rock',
#   'classic rock',
#   'mellow gold',
#   'permanent wave',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'singer-songwriter'],
#  ['alternative rock',
#   'chillwave',
#   'experimental pop',
#   'folk-pop',
#   'freak folk',
#   'garage rock',
#   'indie folk',
#   'indie garage rock',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'lo-fi',
#   'modern rock',
#   'neo-psychedelic',
#   'new rave',
#   'noise pop'],
#  ['abstract hip hop',
#   'alternative hip hop',
#   'escape room',
#   'alternative hip hop',
#   'escape room',
#   'milwaukee hip hop',
#   'escape room',
#   'hip hop',
#   'pop rap',
#   'rap'],
#  ['neo-psychedelic'],
#  ['disco', 'funk', 'post-disco', 'quiet storm'],
#  [],
#  ['underground hip hop'],
#  ['disco',
#   'funk',
#   'jazz funk',
#   'motown',
#   'post-disco',
#   'quiet storm',
#   'soul',
#   'urban contemporary'],
#  ['acid jazz',
#   'afrobeat',
#   'disco',
#   'funk',
#   'indie jazz',
#   'jazz funk',
#   'jazz vibraphone',
#   'post-disco',
#   'quiet storm',
#   'soul',
#   'soul jazz'],
#  ['classic soul',
#   'disco',
#   'funk',
#   'jazz funk',
#   'post-disco',
#   'quiet storm',
#   'soul',
#   'soul jazz'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic'],
#  ['australian indie', 'australian psych', 'neo-psychedelic'],
#  ['austindie',
#   'chamber psych',
#   'freak folk',
#   'funk',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'neo-psychedelic'],
#  ['chillhop', 'vapor twitch', 'alternative r&b', 'indie r&b'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['chillwave',
#   'dream pop',
#   'freak folk',
#   'french shoegaze',
#   'indie garage rock',
#   'indie psych-rock',
#   'indietronica',
#   'neo-psychedelic',
#   'noise pop',
#   'nu gaze',
#   'preverb',
#   'shiver pop'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'folk rock',
#   'mellow gold',
#   'psychedelic rock',
#   'rock'],
#  ['chillhop', 'vapor twitch'],
#  ['chillhop', 'vapor twitch'],
#  ['chillhop', 'vapor twitch'],
#  ['chillhop', 'vapor twitch'],
#  ['chillhop', 'vapor twitch'],
#  ['chillhop', 'vapor twitch'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['boston indie', 'indie garage rock', 'indie psych-rock', 'preverb'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['blues-rock',
#   'classic rock',
#   'folk rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'southern rock'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'neo-psychedelic'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave',
#   'indietronica',
#   'shimmer psych',
#   'vapor soul',
#   'vapor twitch',
#   'alternative r&b',
#   'aussietronica',
#   'electropop',
#   'indie r&b',
#   'vapor soul'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['chillwave', 'indietronica', 'shimmer psych', 'vapor soul', 'vapor twitch'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['uk contemporary r&b'],
#  ['uk contemporary r&b'],
#  ['uk contemporary r&b'],
#  ['uk contemporary r&b'],
#  ['uk contemporary r&b'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['doom metal',
#   'drone metal',
#   'post-doom metal',
#   'post-metal',
#   'psychedelic doom',
#   'retro metal',
#   'sludge metal',
#   'space rock',
#   'stoner metal',
#   'stoner rock'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'cali rap',
#   'gangster rap',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'dance pop',
#   'east coast hip hop',
#   'hip hop',
#   'hip pop',
#   'pop rap',
#   'r&b',
#   'rap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'alternative r&b',
#   'cali rap',
#   'rap',
#   'trap soul',
#   'underground hip hop'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'dancehall'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'deep pop r&b',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'alternative r&b',
#   'dance pop',
#   'deep pop r&b',
#   'hip hop',
#   'hip pop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'urban contemporary'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'atl hip hop'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'alternative r&b',
#   'british soul',
#   'dance pop',
#   'deep pop r&b',
#   'hip pop',
#   'indie r&b',
#   'neo soul',
#   'new jack swing',
#   'quiet storm',
#   'r&b',
#   'urban contemporary'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap',
#   'canadian hip hop',
#   'hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'trap soul',
#   'underground hip hop',
#   'cali rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'underground hip hop',
#   'west coast trap'],
#  ['conscious hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music',
#   'west coast trap'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative rock',
#   'boston rock',
#   'garage rock',
#   'indie rock',
#   'modern rock',
#   'new wave',
#   'noise pop',
#   'permanent wave',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['alternative metal',
#   'alternative rock',
#   'el paso indie',
#   'funk rock',
#   'garage rock',
#   'modern rock',
#   'rock'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'funk',
#   'p funk',
#   'soul',
#   'hip hop'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'neo r&b',
#   'neo soul',
#   'urban contemporary',
#   'alternative r&b',
#   'escape room',
#   'g funk',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'neo r&b',
#   'neo soul',
#   'urban contemporary',
#   'alternative r&b',
#   'escape room',
#   'hip hop'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'quiet storm',
#   'urban contemporary'],
#  ['conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap',
#   'alternative hip hop',
#   'alternative r&b',
#   'escape room',
#   'hip hop',
#   'nc hip hop',
#   'pop rap',
#   'southern hip hop',
#   'trap queen',
#   'underground hip hop'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['conscious hip hop', 'hip hop', 'pop rap', 'rap', 'west coast rap'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['album rock',
#   'art rock',
#   'canadian metal',
#   'classic canadian rock',
#   'classic rock',
#   'hard rock',
#   'metal',
#   'progressive metal',
#   'progressive rock',
#   'rock'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['indie garage rock', 'indie psych-rock', 'indietronica', 'neo-psychedelic'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['album rock', 'classic rock', 'hard rock', 'metal', 'rock', 'stoner rock'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'dance pop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'art pop',
#   'alternative dance',
#   'art pop',
#   'chillwave',
#   'dream pop',
#   'electropop',
#   'experimental pop',
#   'folk-pop',
#   'indie pop',
#   'indie psych-rock',
#   'indie rock',
#   'indie surf',
#   'indietronica',
#   'modern rock',
#   'new rave',
#   'nu gaze',
#   'shimmer pop'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'conscious hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'west coast rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'atl hip hop',
#   'dance pop',
#   'girl group',
#   'hip pop',
#   'maskandi',
#   'new jack swing',
#   'pop',
#   'r&b',
#   'urban contemporary'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'east coast hip hop',
#   'gangster rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'underground hip hop'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop', 'nc hip hop', 'pop', 'pop rap', 'rap'],
#  ['conscious hip hop',
#   'nc hip hop',
#   'pop',
#   'pop rap',
#   'rap',
#   'alternative r&b',
#   'dance pop',
#   'deep pop r&b',
#   'hip pop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'rap',
#   'urban contemporary'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['album rock', 'classic rock', 'piano rock', 'psychedelic rock', 'rock'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  ['alternative country', 'new americana', 'roots rock'],
#  [],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['australian garage punk', 'australian psych', 'neo-psychedelic'],
#  ['jam band'],
#  ['jam band'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['austindie'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'mellow gold',
#   'progressive rock',
#   'rock',
#   'soft rock',
#   'symphonic rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['blues-rock', 'classic rock', 'rock'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['blues',
#   'blues-rock',
#   'classic rock',
#   'classic soul',
#   'electric blues',
#   'folk rock',
#   'funk',
#   'jazz blues',
#   'louisiana blues',
#   'modern blues',
#   'new orleans blues',
#   'piano blues',
#   'psychedelic rock',
#   'roots rock',
#   'soul'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
#   'progressive rock',
#   'psychedelic rock',
#   'rock',
#   'symphonic rock'],
#  ['album rock',
#   'art rock',
#   'classic rock',
# ...
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz piano',
#   'soul jazz',
#   'stride',
#   'jazz double bass',
#   'avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz drums',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'big band',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz piano',
#   'soul jazz',
#   'stride',
#   'jazz double bass',
#   'avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz drums',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'big band',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz piano',
#   'soul jazz',
#   'stride',
#   'jazz double bass',
#   'avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz drums',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'big band',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride',
#   'vocal jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz piano',
#   'soul jazz',
#   'stride',
#   'jazz double bass',
#   'avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz drums',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz double bass',
#   'jazz electric bass',
#   'jazz fusion'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'vocal jazz'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['american modern classical', 'bebop', 'cool jazz', 'jazz', 'jazz piano'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz trumpet',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz'],
#  ['avant-garde jazz',
#   'bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz saxophone',
#   'vocal jazz'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock'],
#  ['album rock',
#   'blues-rock',
#   'classic rock',
#   'country rock',
#   'electric blues',
#   'folk rock',
#   'hard rock',
#   'jam band',
#   'mellow gold',
#   'psychedelic rock',
#   'rock',
#   'roots rock',
#   'soft rock',
#   'southern rock']]

# %%
for art in all_songs[0]['track']['artists']:
    print(art[])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5IcR3N7QB1j6KBL8eImZ8m'},
#   'href': 'https://api.spotify.com/v1/artists/5IcR3N7QB1j6KBL8eImZ8m',
#   'id': '5IcR3N7QB1j6KBL8eImZ8m',
#   'name': 'ScHoolboy Q',
#   'type': 'artist',
#   'uri': 'spotify:artist:5IcR3N7QB1j6KBL8eImZ8m'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/17lzZA2AlOHwCwFALHttmp'},
#   'href': 'https://api.spotify.com/v1/artists/17lzZA2AlOHwCwFALHttmp',
#   'id': '17lzZA2AlOHwCwFALHttmp',
#   'name': '2 Chainz',
#   'type': 'artist',
#   'uri': 'spotify:artist:17lzZA2AlOHwCwFALHttmp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/37Qsf5KCKljH7mL134xp4k'},
#   'href': 'https://api.spotify.com/v1/artists/37Qsf5KCKljH7mL134xp4k',
#   'id': '37Qsf5KCKljH7mL134xp4k',
#   'name': 'Saudi',
#   'type': 'artist',
#   'uri': 'spotify:artist:37Qsf5KCKljH7mL134xp4k'}]
